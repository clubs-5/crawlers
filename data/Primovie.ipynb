# %%
import pandas as pd

df = pd.read_csv('/home/lmin/Desktop/test/crawlers/data/Prime_movie1970_1954.csv')#匯入資料
df = pd.read_csv('/home/lmin/Desktop/test/crawlers/data/Prime_movie1989_1947.csv')
df = pd.read_csv('/home/lmin/Desktop/test/crawlers/data/Prime_movie2020_1990.csv')
df.fillna('NaN')#將空值欄位填入NaN
ndf = df.drop(['style'], axis=1)#刪除style,裡面太多無用訊息
ndf.sort_values(by='rating_avg', ascending=False)#評分由高至低排序
# Out:
#      rating_total  rating_avg  \
# 234            27         9.7
# 1490    1,413,022         9.5
# 461        93,293         9.5
# 223         3,784         9.4
# 1469      164,369         9.4
# ...           ...         ...
# 2575          NaN         NaN
# 2613          NaN         NaN
# 2623          NaN         NaN
# 2636          NaN         NaN
# 2660          NaN         NaN
#
#                                                finalist  \
# 234                              The Line (2019) - IMDb
# 1490          Breaking Bad (TV Series 2008–2013) - IMDb
# 461        Planet Earth II (TV Mini-Series 2016) - IMDb
# 223   Seven Worlds One Planet (TV Mini-Series 2019) ...
# 1469          Planet Earth (TV Mini-Series 2006) - IMDb
# ...                                                 ...
# 2575              Sunday Best (TV Series 1991– ) - IMDb
# 2613                    Perlman in Russia (1992) - IMDb
# 2623             Pavarotti on Miami Beach (1996) - IMDb
# ...

# %%
df.to_csv('New_primovie.csv', encoding='utf-8')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2677 entries, 0 to 2676
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rating_total       2580 non-null   object
#  1   rating_avg         2580 non-null   float64
#  2   finalist           2677 non-null   object
#  3   movie_description  2677 non-null   object
#  4   cast               2621 non-null   object
#  5   language           2651 non-null   object
#  6   style              2677 non-null   object
#  7   country            2657 non-null   object
#  8   company            2677 non-null   object
#  9   film_location      890 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 209.3+ KB
